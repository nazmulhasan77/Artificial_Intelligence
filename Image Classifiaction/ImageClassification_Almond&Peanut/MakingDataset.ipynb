# %%
import cv2
import os

# -------- CONFIGURATION --------
image_path = "a1.jpg"  # Input image
output_dir = "dataset_almond"           # Folder to save cropped almonds
rows, cols = 3, 11                      # Grid structure (3 rows × 11 columns)

# Create output directory if not exist
os.makedirs(output_dir, exist_ok=True)

# Read the image
image = cv2.imread(image_path)
h, w, _ = image.shape

# Compute cell size
cell_h = h // rows
cell_w = w // cols

count = 0
for i in range(rows):
    for j in range(cols):
        y1 = i * cell_h
        y2 = (i + 1) * cell_h
        x1 = j * cell_w
        x2 = (j + 1) * cell_w

        # Crop almond
        crop = image[y1:y2, x1:x2]

        # Optional: add small margin to avoid cutting edges
        margin = 10
        y1 = max(y1 - margin, 0)
        y2 = min(y2 + margin, h)
        x1 = max(x1 - margin, 0)
        x2 = min(x2 + margin, w)
        crop = image[y1:y2, x1:x2]

        # Save cropped image
        filename = f"almond_{i+1}_{j+1}.jpg"
        cv2.imwrite(os.path.join(output_dir, filename), crop)
        count += 1

print(f"✅ Cropped and saved {count} almond images to '{output_dir}/'")
# Out:
# ✅ Cropped and saved 33 almond images to 'dataset_almond/'

# %%
import os
import cv2

# -------- CONFIGURATION --------
input_dir = "Peanut"               # Folder containing your original images
output_dir = "Peanut_images"             # Folder to save resized images
class_name = "Peanut"                    # Change this to your class name
device_name = "iPhone12ProMax"           # Change this to your device name
resolution = "32x32"                     # Target resolution for naming
target_size = (32, 32)                   # Width, Height

# -------- CREATE OUTPUT FOLDER --------
os.makedirs(output_dir, exist_ok=True)

# -------- PROCESS IMAGES --------
count = 1
for filename in os.listdir(input_dir):
    if filename.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tiff", ".webp")):
        img_path = os.path.join(input_dir, filename)
        img = cv2.imread(img_path)
        if img is None:
            print(f"⚠️ Skipping invalid image: {filename}")
            continue

        # Resize image
        resized_img = cv2.resize(img, target_size)

        # Create new filename
        new_name = f"{class_name}_{device_name}_{resolution}_{count}.jpg"
        output_path = os.path.join(output_dir, new_name)

        # Save resized image
        cv2.imwrite(output_path, resized_img)
        print(f"✅ Saved: {new_name}")
        count += 1

print("\n🎉 All images resized and saved successfully!")
# Out:
# ✅ Saved: Peanut_iPhone12ProMax_32x32_1.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_2.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_3.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_4.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_5.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_6.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_7.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_8.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_9.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_10.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_11.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_12.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_13.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_14.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_15.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_16.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_17.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_18.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_19.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_20.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_21.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_22.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_23.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_24.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_25.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_26.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_27.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_28.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_29.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_30.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_31.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_32.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_33.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_34.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_35.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_36.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_37.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_38.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_39.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_40.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_41.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_42.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_43.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_44.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_45.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_46.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_47.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_48.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_49.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_50.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_51.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_52.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_53.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_54.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_55.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_56.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_57.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_58.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_59.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_60.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_61.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_62.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_63.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_64.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_65.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_66.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_67.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_68.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_69.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_70.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_71.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_72.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_73.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_74.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_75.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_76.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_77.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_78.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_79.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_80.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_81.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_82.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_83.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_84.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_85.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_86.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_87.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_88.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_89.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_90.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_91.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_92.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_93.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_94.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_95.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_96.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_97.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_98.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_99.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_100.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_101.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_102.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_103.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_104.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_105.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_106.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_107.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_108.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_109.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_110.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_111.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_112.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_113.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_114.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_115.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_116.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_117.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_118.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_119.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_120.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_121.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_122.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_123.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_124.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_125.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_126.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_127.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_128.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_129.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_130.jpg
# ✅ Saved: Peanut_iPhone12ProMax_32x32_131.jpg
#
# 🎉 All images resized and saved successfully!
